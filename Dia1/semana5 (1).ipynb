# %%
def suma():

  a = int (input("escribe primer numero"))
  b = int (input("escribe el segundo numero"))

  return a + b

# %%
def nombre(nombre, teDeseo):
    print(f"Hola {nombre} , desde esta funcion!, te deseo {teDeseo}")

# %%
nombre("Rajaa", "buena suerte :)")
nombre("Rajaa", "muy buena suerte ;D")
# Out:
# Hola Rajaa , desde esta funcion!, te deseo buena suerte :)
# Hola Rajaa , desde esta funcion!, te deseo muy buena suerte ;D

# %%
primos = [2,3,5,7,11,13,17,19,23]
for valor in primos: #Busqueda
  if valor == 1:
    print (valor)

# %%
primos = [2,3,5,7,11,13,17,19,23]
aux = []
for primos in primos: 
   aux.append(primos)
print(aux)
# Out:
# [2, 3, 5, 7, 11, 13, 17, 19, 23]

# %%
for x in range (5,):
  print (x)
# Out:
# 5
# 7
# 9
# 11
# 13
# 15
# 17
# 19
